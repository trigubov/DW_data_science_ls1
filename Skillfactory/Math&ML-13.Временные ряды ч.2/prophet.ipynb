# %%
#!pip install prophet

# %%
#!pip install neuralprophet

# %%
import pandas as pd

from prophet import Prophet
from neuralprophet import NeuralProphet

url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'

df = pd.read_csv(url)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\IDE\Skillfactory\Math&ML-13.Временные ряды ч.2\prophet.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/c%3A/IDE/Skillfactory/Math%26ML-13.%D0%92%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%B5%20%D1%80%D1%8F%D0%B4%D1%8B%20%D1%87.2/prophet.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/IDE/Skillfactory/Math%26ML-13.%D0%92%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%B5%20%D1%80%D1%8F%D0%B4%D1%8B%20%D1%87.2/prophet.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from prophet import Prophet
# ----> <a href='vscode-notebook-cell:/c%3A/IDE/Skillfactory/Math%26ML-13.%D0%92%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%B5%20%D1%80%D1%8F%D0%B4%D1%8B%20%D1%87.2/prophet.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from neuralprophet import NeuralProphet
#       <a href='vscode-notebook-cell:/c%3A/IDE/Skillfactory/Math%26ML-13.%D0%92%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%B5%20%D1%80%D1%8F%D0%B4%D1%8B%20%D1%87.2/prophet.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'
#       <a href='vscode-notebook-cell:/c%3A/IDE/Skillfactory/Math%26ML-13.%D0%92%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%B5%20%D1%80%D1%8F%D0%B4%D1%8B%20%D1%87.2/prophet.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> df = pd.read_csv(url)
#
# ModuleNotFoundError: No module named 'neuralprophet'

# %%
model = Prophet()
model.fit(df)
# Out:
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] done processing

# %%
future_df = model.make_future_dataframe(periods=365)

future_df.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast_df = model.predict(future_df)
forecast_df[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206964    7.453006    8.979440
# 3266 2017-01-16  8.531958    7.772577    9.274655
# 3267 2017-01-17  8.319376    7.560697    9.036681
# 3268 2017-01-18  8.151991    7.394800    8.869921
# 3269 2017-01-19  8.163908    7.426650    8.896717

# %%
fig = model.plot(forecast_df)
# Out:
# c:\Users\trigubov\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\trigubov\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %% [markdown]
# Чтобы увидеть компоненты ряда, можно использовать метод Prophet.plot_components. По умолчанию предоставляются тренд и годовая и недельная сезонность временного ряда.

# %%
fig = model.plot_components(forecast_df)
# Out:
# c:\Users\trigubov\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\trigubov\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\trigubov\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# # NEURALPROPHET

# %%
# установка NeuralProphet в варианте Live для Jupiter Notebook
#!pip install neuralprophet[live]
